# %% [markdown]
# ### 역발상 종목 선별

# %%
import sys
import pandas as pd
from tqdm import tqdm
sys.path.append('../')
from stock_screener.data_reader import *

# %%
# 최근 거래일자 획득
date = get_recent_biz_day()

#해당일의 종목별 지표 정보 획득
per_pbr_divdend_data = get_per_pbr_dividend2(date)

# %%
# 종목의 업종분류 획득 (WICS)
# %time sector_data = get_sector(date)
# Out:
# Wall time: 38.9 s

# %%
# 업종별로 PER / PBR / 배당수익률 정보 join
sector_data2 = {k: pd.merge(v, 
                          per_pbr_divdend_data, 
                          on=['종목코드']).sort_values('PER')
                for k, v in sector_data.items()}

# %%
sector_data2['G1010']
# a = sector_data.items()
# Out:
#        종목명_x    종목코드       섹터명      종목명_y      종가     PER   PBR  배당수익률  \
# 16      대성산업  128820  WICS 에너지      대성산업     4235    3.00  0.38   0.00
# 4    SK디스커버리  006120  WICS 에너지   SK디스커버리    46300    3.54  0.49   2.16
# 26    중앙에너비스  000440  WICS 에너지    중앙에너비스    15900    3.84  1.61   3.02
# 25    경동인베스트  012320  WICS 에너지    경동인베스트    35100    5.05  0.20   1.42
# 15      미창석유  003650  WICS 에너지      미창석유    79000    6.09  0.50   2.66
# 23       스페코  013810  WICS 에너지       스페코     5300    8.53  1.89   0.94
# 6      KG케미칼  001390  WICS 에너지     KG케미칼    31400    9.35  1.07   1.27
# 14       SDN  099220  WICS 에너지       SDN     1855   10.54  0.99   0.00
# 8      한국쉘석유  002960  WICS 에너지     한국쉘석유   276500   17.11  3.66   5.06
# 17      극동유화  014530  WICS 에너지      극동유화     3735   17.54  0.76   3.75
# 20      흥구석유  024060  WICS 에너지      흥구석유     6830   20.70  1.29   2.20
# 13    제이씨케미칼  137950  WICS 에너지    제이씨케미칼     8330   23.33  1.83   1.08
# 5     SGC에너지  005090  WICS 에너지    SGC에너지    43900   24.50  1.14   3.42
# 12  현대에너지솔루션  322000  WICS 에너지  현대에너지솔루션    20400   36.69  0.70   0.98
# 11      위즈코프  038620  WICS 에너지      위즈코프     2850   53.77  3.70   0.70
# 27       윌링스  313760  WICS 에너지       윌링스    19150  290.15  2.57   0.42
# 0    SK이노베이션  096770  WICS 에너지   SK이노베이션   203000     NaN  1.31   0.00
# 1      S-Oil  010950  WICS 에너지     S-Oil    90600     NaN  1.86   0.00
# 2    현대중공업지주  267250  WICS 에너지   현대중공업지주    57500     NaN  0.65   6.43
# 3         GS  078930  WICS 에너지        GS    40250     NaN  0.46   4.72
# 7       이아이디  093230  WICS 에너지      이아이디      307     NaN  1.54   0.00
# 9      세원이앤씨  091090  WICS 에너지     세원이앤씨     1220     NaN  0.99   0.00
# 10      오르비텍  046120  WICS 에너지      오르비텍     6220     NaN  3.15   0.00
# 18     젬백스지오  041590  WICS 에너지     젬백스지오     1105     NaN  1.04   0.00
# 19     에스에너지  095910  WICS 에너지     에스에너지     4360     NaN  0.71   1.15
# 21     코드네이처  078940  WICS 에너지     코드네이처     2400     NaN  4.08   0.00
# 22    지엔원에너지  270520  WICS 에너지    지엔원에너지     3090     NaN  3.18   0.00
# 24        서남  294630  WICS 에너지        서남     3620     NaN  6.09   0.00
#
#          기준일
# 16  20211207
# 4   20211207
# 26  20211207
# 25  20211207
# 15  20211207
# 23  20211207
# 6   20211207
# 14  20211207
# 8   20211207
# 17  20211207
# 20  20211207
# 13  20211207
# 5   20211207
# 12  20211207
# 11  20211207
# 27  20211207
# 0   20211207
# 1   20211207
# 2   20211207
# 3   20211207
# 7   20211207
# 9   20211207
# 10  20211207
# 18  20211207
# 19  20211207
# 21  20211207
# 22  20211207
# 24  20211207

# %%
sector_code_name = {k: ' '.join(v['섹터명'].iloc[0].split()[1:]) \
                    for k,v in sector_data2.items()}

# %%
# PER 평균값 데이터
per_mean = dict()

# 시장 PER 평균
per_mean['전체'] = per_pbr_divdend_data['PER'].mean()

# 업종별 PER 평균
for k,v in sector_data2.items():
    per_mean[sector_code_name[k]] = v['PER'].mean()

# %%
per_mean_df = pd.DataFrame(per_mean.items())
per_mean_df.columns = ['업종', '평균PER']

# %%
per_mean_df.sort_values('평균PER')
# Out:
#              업종       평균PER
# 20          부동산    7.780000
# 19           보험    9.874286
# 17           증권   10.298696
# 18       다각화된금융   16.117727
# 4     상업서비스와공급품   18.040526
# 28         유틸리티   22.092500
# 8   호텔,레스토랑,레저등   23.476667
# 16           은행   25.687273
# 13    가정용품과개인용품   26.876000
# 25        디스플레이   29.303462
# 12     식품,음료,담배   29.776027
# 1           에너지   33.358125
# 11   식품과기본식료품소매   37.011667
# 5            운송   40.787826
# 21    소프트웨어와서비스   42.916667
# 7      내구소비재와의류   46.839205
# 3           자본재   49.252600
# 26      전기통신서비스   53.442500
# 6        자동차와부품   67.786818
# 22    기술하드웨어와장비   74.524623
# 15      제약과생물공학   76.997264
# 23    반도체와반도체장비   77.695000
# 10        교육서비스   80.801667
# 0            전체   86.369993
# 14   건강관리장비와서비스  105.326667
# 27   미디어와엔터테인먼트  113.262187
# 24     전자와 전기제품  114.550811
# 9        소매(유통)  121.488500
# 2            소재  284.357964

# %%
def pass_criteria(code):

    # 재무제표 데이터에서 원하는 조건을 만족하는 경우 True, 아니면 False 반환
    annual_data, quarter_data = get_financial_summary(code)

    try:
        # 최근 3개년 영업이익 흑자
        num_year = 3
        annual_profit = annual_data['영업이익'].tail(num_year)
        if not all(x > 0 for x in annual_profit):
            return False

        # 최근 3개년 ROE >= 8
        num_year = 3
        annual_roe = annual_data['ROE'].tail(num_year)
        if not all(x >= 8 for x in annual_roe):
            return False

        # 최근 3개년 배당수익률 >= 2
        num_year = 3
        annual_dvd = annual_data['배당수익률'].tail(num_year)
        if not all(x >= 2 for x in annual_dvd):
            return False

        # 최근 4분기 영업이익 흑자
        num_quarter = 4
        quarter_profit = quarter_data['영업이익'].tail(num_quarter)
        if not all(x > 0 for x in quarter_profit):
            return False
    except:
        # 체크하려는 값이 nan인 경우거나, 데이터가 불충분한 경우
        return False

    return True

# %%
# 기준값 만족하는 종목을 업종별로 스크리닝
corp_by_sector = dict()

for sector_code, sector_df in tqdm(sector_data2.items()):

    sector_name = sector_code_name[sector_code]
    cutoff_per = sector_df['PER'].quantile(0.5)
    
    # PER이 낮은 종목 -> 높은 종목 순으로 체크
    for _, x in sector_df.iterrows():

        if pass_criteria(x['종목코드']):
            corp_by_sector[sector_name] = dict(x)
            break

        # 업종 PER의 중위수보다 작은 PER을 갖는 종목만 고려한다
        elif x['PER'] >= cutoff_per:
            break

    # 적절한 종목이 없는 경우, 빈값을 채운다
    if sector_name not in corp_by_sector:
        corp_by_sector[sector_name] = {'기준일':x['기준일']}
# Out:
# 100%|██████████| 28/28 [08:26<00:00, 18.08s/it]

# %%
len(corp_by_sector)
# Out:
# 28

# %%
corp_by_sector_df = pd.DataFrame(corp_by_sector.values())
corp_by_sector_df['업종'] = corp_by_sector.keys()
corp_by_sector_df['업종평균PER'] = [per_mean[k] for k in corp_by_sector]
corp_by_sector_df = corp_by_sector_df[['기준일', '업종', '종목명_x','종목코드', '종가', 
                                       'PER', 'PBR', '배당수익률', '업종평균PER']]
corp_by_sector_df.fillna('', inplace=True)

# %%
corp_by_sector_df
# Out:
#          기준일           업종     종목명_x    종목코드       종가    PER   PBR 배당수익률  \
# 0   20211207          에너지
# 1   20211207           소재     애경케미칼  161000  11100.0   7.89   0.9  3.15
# 2   20211207          자본재      태영건설  009410  10500.0    1.1  0.66   3.1
# 3   20211207    상업서비스와공급품    고려신용정보  049720   8750.0  11.82  4.29  3.14
# 4   20211207           운송
# 5   20211207       자동차와부품     대유에이피  290120   5980.0  11.28   1.3  3.34
# 6   20211207     내구소비재와의류     쿠쿠홀딩스  192400  18800.0   5.47  0.88  3.51
# 7   20211207  호텔,레스토랑,레저등
# 8   20211207       소매(유통)
# 9   20211207        교육서비스    씨엠에스에듀  225330   7150.0  21.47  3.13  3.64
# 10  20211207   식품과기본식료품소매
# 11  20211207     식품,음료,담배      KT&G  033780  85700.0    9.2   1.3   5.6
# 12  20211207    가정용품과개인용품
# 13  20211207   건강관리장비와서비스
# 14  20211207      제약과생물공학
# 15  20211207           은행    JB금융지주  175330   8510.0    4.8  0.45  4.39
# 16  20211207           증권  이베스트투자증권  078020   8620.0   3.57  0.78  6.38
# 17  20211207       다각화된금융      리드코프  012700   9160.0   5.15  0.59  8.73
# 18  20211207           보험     메리츠화재  000060  32550.0   8.44  1.47  3.93
# 19  20211207          부동산    한국자산신탁  123890   4185.0   3.94  0.67  5.26
# 20  20211207    소프트웨어와서비스        윈스  136540  16800.0   10.1  1.61  2.38
# 21  20211207    기술하드웨어와장비    에스에이엠티  031330   4375.0   9.94  1.72  3.43
# 22  20211207    반도체와반도체장비      삼성전자  005930  77400.0  20.15  1.96  3.87
# 23  20211207     전자와 전기제품
# 24  20211207        디스플레이       아바코  083930  11300.0  10.43  1.24  2.65
# 25  20211207      전기통신서비스
# 26  20211207   미디어와엔터테인먼트     에코마케팅  230360  17550.0  10.73  3.94   5.3
# 27  20211207         유틸리티
#
#        업종평균PER
# 0    33.358125
# 1   284.357964
# 2    49.252600
# 3    18.040526
# 4    40.787826
# 5    67.786818
# 6    46.839205
# 7    23.476667
# 8   121.488500
# 9    80.801667
# 10   37.011667
# 11   29.776027
# 12   26.876000
# 13  105.326667
# 14   76.997264
# 15   25.687273
# 16   10.298696
# 17   16.117727
# 18    9.874286
# 19    7.780000
# 20   42.916667
# 21   74.524623
# 22   77.695000
# 23  114.550811
# 24   29.303462
# 25   53.442500
# 26  113.262187
# 27   22.092500
