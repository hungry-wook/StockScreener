# %% [markdown]
# ### 역발상 종목 선별

# %%
import sys
import pandas as pd
from tqdm import tqdm
sys.path.append('../')
from stock_screener.data_reader import *

# %%
# 최근 거래일자 획득
date = get_recent_biz_day()

#해당일의 종목별 지표 정보 획득
per_pbr_divdend_data = get_per_pbr_dividend(date)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21468/3696301518.py in <module>
#       3
#       4 #해당일의 종목별 지표 정보 획득
# ----> 5 per_pbr_divdend_data = get_per_pbr_dividend(date)
#
# c:\Users\YLSH\sungdune\StockScreener\stock_screener\data_reader\data_reader.py in get_per_pbr_dividend(date)
#     147         'per':'PER',
#     148         'work_dt':'기준일'
# --> 149     }
#     150     df = df.rename(columns=columns)
#     151     df =df[['종목명', '종목코드', '기준일', '종가',
#
# UnboundLocalError: local variable 'df' referenced before assignment

# %%
# 종목의 업종분류 획득 (WICS)
# %time sector_data = get_sector(date)
# Out:
# CPU times: user 246 ms, sys: 36.3 ms, total: 282 ms
# Wall time: 15.3 s

# %%
# 업종별로 PER / PBR / 배당수익률 정보 join
sector_data = {k:pd.merge(v, 
                          per_pbr_divdend_data, 
                          on=['종목명','종목코드']).sort_values('PER')
                for k,v in sector_data.items()}

# %%
sector_code_name = {k: ' '.join(v['섹터명'].iloc[0].split()[1:]) \
                    for k,v in sector_data.items()}

# %%
# PER 평균값 데이터
per_mean = dict()

# 시장 PER 평균
per_mean['전체'] = per_pbr_divdend_data['PER'].mean()

# 업종별 PER 평균
for k,v in sector_data.items():
    per_mean[sector_code_name[k]] = v['PER'].mean()

# %%
per_mean_df = pd.DataFrame(per_mean.items())
per_mean_df.columns = ['업종', '평균PER']

# %%
per_mean_df.sort_values('평균PER')
# Out:
#              업종       평균PER
# 16           은행    4.152222
# 17           증권    7.980000
# 18       다각화된금융   12.805000
# 28         유틸리티   14.353529
# 19           보험   16.777500
# 20          부동산   18.520000
# 4     상업서비스와공급품   20.272353
# 5            운송   24.040909
# 11   식품과기본식료품소매   25.093333
# 13    가정용품과개인용품   28.802500
# 14   건강관리장비와서비스   35.330000
# 12     식품,음료,담배   39.421475
# 2            소재   40.015549
# 10        교육서비스   41.013750
# 3           자본재   43.584677
# 27   미디어와엔터테인먼트   45.982222
# 25        디스플레이   47.773929
# 6        자동차와부품   53.412778
# 22    기술하드웨어와장비   57.051371
# 7      내구소비재와의류   58.276747
# 0            전체   63.632384
# 24     전자와 전기제품   64.282059
# 21    소프트웨어와서비스   68.274805
# 26      전기통신서비스   73.251429
# 23    반도체와반도체장비   73.402048
# 9        소매(유통)   74.660000
# 1           에너지   97.850000
# 15      제약과생물공학  185.368257
# 8   호텔,레스토랑,레저등  509.983571

# %%
def pass_criteria(code):

    # 재무제표 데이터에서 원하는 조건을 만족하는 경우 True, 아니면 False 반환
    annual_data, quarter_data = get_financial_summary(code)

    try:
        # 최근 3개년 영업이익 흑자
        num_year = 3
        annual_profit = annual_data['영업이익'].tail(num_year)
        if not all(x > 0 for x in annual_profit):
            return False

        # 최근 3개년 ROE >= 8
        num_year = 3
        annual_roe = annual_data['ROE'].tail(num_year)
        if not all(x >= 8 for x in annual_roe):
            return False

        # 최근 3개년 배당수익률 >= 2
        num_year = 3
        annual_dvd = annual_data['배당수익률'].tail(num_year)
        if not all(x >= 2 for x in annual_dvd):
            return False

        # 최근 4분기 영업이익 흑자
        num_quarter = 4
        quarter_profit = quarter_data['영업이익'].tail(num_quarter)
        if not all(x > 0 for x in quarter_profit):
            return False
    except:
        # 체크하려는 값이 nan인 경우거나, 데이터가 불충분한 경우
        return False

    return True

# %%
# 기준값 만족하는 종목을 업종별로 스크리닝
corp_by_sector = dict()

for sector_code, sector_df in tqdm(sector_data.items()):

    sector_name = sector_code_name[sector_code]
    cutoff_per = sector_df['PER'].quantile(0.5)
    
    # PER이 낮은 종목 -> 높은 종목 순으로 체크
    for _, x in sector_df.iterrows():

        if pass_criteria(x['종목코드']):
            corp_by_sector[sector_name] = dict(x)
            break

        # 업종 PER의 중위수보다 작은 PER을 갖는 종목만 고려한다
        elif x['PER'] >= cutoff_per:
            break

    # 적절한 종목이 없는 경우, 빈값을 채운다
    if sector_name not in corp_by_sector:
        corp_by_sector[sector_name] = {'기준일':x['기준일']}
# Out:
# 100%|██████████| 28/28 [01:51<00:00,  3.97s/it]

# %%
len(corp_by_sector)
# Out:
# 28

# %%
corp_by_sector_df = pd.DataFrame(corp_by_sector.values())
corp_by_sector_df['업종'] = corp_by_sector.keys()
corp_by_sector_df['업종평균PER'] = [per_mean[k] for k in corp_by_sector]
corp_by_sector_df = corp_by_sector_df[['기준일', '업종', '종목명', '종목코드', '종가', 
                                       'PER', 'PBR', '배당수익률', '업종평균PER']]
corp_by_sector_df.fillna('', inplace=True)

# %%
corp_by_sector_df
# Out:
#          기준일           업종      종목명    종목코드      종가    PER   PBR 배당수익률  \
# 0   20201113          에너지     극동유화  014530    3395   8.05   0.7  4.71
# 1   20201113           소재     케이디켐  221980   12600   6.57  0.66  3.97
# 2   20201113          자본재     삼호개발  010960    4130   4.55  0.54   4.6
# 3   20201113    상업서비스와공급품   고려신용정보  049720    5500  11.55  3.49  4.55
# 4   20201113           운송    KSS해운  044450   10800  10.44   0.9   2.5
# 5   20201113       자동차와부품
# 6   20201113     내구소비재와의류    쿠쿠홀딩스  192400   96000   7.51  1.01  3.13
# 7   20201113  호텔,레스토랑,레저등
# 8   20201113       소매(유통)    GS홈쇼핑  028150  139300    7.6   0.8  4.67
# 9   20201113        교육서비스    디지털대성  068930    7480   9.82  2.03  4.01
# 10  20201113   식품과기본식료품소매
# 11  20201113     식품,음료,담배     KT&G  033780   84700  10.32  1.34  5.19
# 12  20201113    가정용품과개인용품
# 13  20201113   건강관리장비와서비스
# 14  20201113      제약과생물공학   JW생명과학  234080   19850  14.33  2.56  2.52
# 15  20201113           은행
# 16  20201113           증권    메리츠증권  008560    3575   3.87  0.63  5.59
# 17  20201113       다각화된금융     리드코프  012700    6860   4.42  0.49  2.19
# 18  20201113           보험  메리츠금융지주  138040   10100   3.61  0.52  5.45
# 19  20201113          부동산   한국토지신탁  034830    1850   4.12  0.53  5.95
# 20  20201113    소프트웨어와서비스     인포바인  115310   18450   4.46  0.69  4.88
# 21  20201113    기술하드웨어와장비   에스에이엠티  031330    2400   6.32  1.01  5.83
# 22  20201113    반도체와반도체장비
# 23  20201113     전자와 전기제품
# 24  20201113        디스플레이
# 25  20201113      전기통신서비스
# 26  20201113   미디어와엔터테인먼트   스카이라이프  053210    9300   8.11  0.64  3.76
# 27  20201113         유틸리티    한전KPS  051600   29200   8.57  1.24  6.58
#
#        업종평균PER
# 0    97.850000
# 1    40.015549
# 2    43.584677
# 3    20.272353
# 4    24.040909
# 5    53.412778
# 6    58.276747
# 7   509.983571
# 8    74.660000
# 9    41.013750
# 10   25.093333
# 11   39.421475
# 12   28.802500
# 13   35.330000
# 14  185.368257
# 15    4.152222
# 16    7.980000
# 17   12.805000
# 18   16.777500
# 19   18.520000
# 20   68.274805
# 21   57.051371
# 22   73.402048
# 23   64.282059
# 24   47.773929
# 25   73.251429
# 26   45.982222
# 27   14.353529
